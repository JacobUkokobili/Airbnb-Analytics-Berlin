# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
calendar_summary = pd.read_csv("../calendar_summary.csv")
listings = pd.read_csv("../listings.csv")
listings_summary = pd.read_csv("../listings_summary.csv")
neighbourhoods = pd.read_csv("../neighbourhoods.csv")
reviews = pd.read_csv("../reviews.csv")
reviews_summary = pd.read_csv("../reviews_summary.csv")

# %%
listings.isnull().sum()
# Out:
# id                                   0
# name                                59
# host_id                              0
# host_name                           26
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       3908
# reviews_per_month                 3914
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
listings = listings.drop(listings[["name","host_name","last_review"]],axis=1)

# %%
listings
# Out:
#              id    host_id     neighbourhood_group             neighbourhood  \
# 0          2015       2217                   Mitte           Brunnenstr. Süd
# 1          2695       2986                  Pankow  Prenzlauer Berg Nordwest
# 2          3176       3718                  Pankow   Prenzlauer Berg Südwest
# 3          3309       4108  Tempelhof - Schöneberg           Schöneberg-Nord
# 4          7071      17391                  Pankow            Helmholtzplatz
# ...         ...        ...                     ...                       ...
# 22547  29856708   87555909                   Mitte           Brunnenstr. Süd
# 22548  29857108   67537363  Tempelhof - Schöneberg           Schöneberg-Nord
# 22549  29864272    3146923                  Pankow   Prenzlauer Berg Südwest
# 22550  29866805   36961901                   Mitte            Alexanderplatz
# 22551  29867352  177464875                Neukölln         Schillerpromenade
#
# ...

# %%
listings["room_type"].value_counts()
# Out:
# Private room       11534
# Entire home/apt    10722
# Shared room          296
# Name: room_type, dtype: int64

# %%
listings = listings.rename(columns={"id": "listing_id"})

# %%
listings
# Out:
#        listing_id    host_id     neighbourhood_group  \
# 0            2015       2217                   Mitte
# 1            2695       2986                  Pankow
# 2            3176       3718                  Pankow
# 3            3309       4108  Tempelhof - Schöneberg
# 4            7071      17391                  Pankow
# ...           ...        ...                     ...
# 22547    29856708   87555909                   Mitte
# 22548    29857108   67537363  Tempelhof - Schöneberg
# 22549    29864272    3146923                  Pankow
# 22550    29866805   36961901                   Mitte
# 22551    29867352  177464875                Neukölln
#
#                   neighbourhood   latitude  longitude        room_type  price  \
# 0               Brunnenstr. Süd  52.534537  13.402557  Entire home/apt     60
# 1      Prenzlauer Berg Nordwest  52.548513  13.404553     Private room     17
# 2       Prenzlauer Berg Südwest  52.534996  13.417579  Entire home/apt     90
# ...

# %%
calendar_summary = calendar_summary.drop("price", axis=1)

# %%
calendar_summary["available"].value_counts()
# Out:
# f    6430639
# t    1800841
# Name: available, dtype: int64

# %%
listings_summary.head(1)
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2015  https://www.airbnb.com/rooms/2015  20181107122246   2018-11-07
#
#                                                name  \
# 0  Berlin-Mitte Value! Quiet courtyard/very central
#
#                                              summary  \
# 0  Great location!  30 of 75 sq meters. This wood...
#
#                                                space  \
# 0  A+++ location! This „Einliegerwohnung“ is an e...
#
#                                          description experiences_offered  \
# 0  Great location!  30 of 75 sq meters. This wood...                none
#
#                                neighborhood_overview  ... requires_license  \
# 0  It is located in the former East Berlin area o...  ...                t
#
#   license jurisdiction_names instant_bookable is_business_travel_ready  \
# 0     NaN                NaN                f                        f
#
# ...

# %%
summfeat = listings_summary[["id","instant_bookable","is_business_travel_ready","require_guest_phone_verification","require_guest_profile_picture"]]

# %%
summfeat = summfeat.rename(columns={"id": "listing_id"})

# %%
listings = listings.merge(summfeat, on="listing_id")

# %%
listings["instant_bookable"].value_counts()
# Out:
# f    15518
# t     7034
# Name: instant_bookable, dtype: int64

# %%
listings
# Out:
#        listing_id    host_id     neighbourhood_group  \
# 0            2015       2217                   Mitte
# 1            2695       2986                  Pankow
# 2            3176       3718                  Pankow
# 3            3309       4108  Tempelhof - Schöneberg
# 4            7071      17391                  Pankow
# ...           ...        ...                     ...
# 22547    29856708   87555909                   Mitte
# 22548    29857108   67537363  Tempelhof - Schöneberg
# 22549    29864272    3146923                  Pankow
# 22550    29866805   36961901                   Mitte
# 22551    29867352  177464875                Neukölln
#
#                   neighbourhood   latitude  longitude        room_type  price  \
# 0               Brunnenstr. Süd  52.534537  13.402557  Entire home/apt     60
# 1      Prenzlauer Berg Nordwest  52.548513  13.404553     Private room     17
# 2       Prenzlauer Berg Südwest  52.534996  13.417579  Entire home/apt     90
# ...

# %%
listings.isna().sum()
# Out:
# listing_id                             0
# host_id                                0
# neighbourhood_group                    0
# neighbourhood                          0
# latitude                               0
# longitude                              0
# room_type                              0
# price                                  0
# minimum_nights                         0
# number_of_reviews                      0
# reviews_per_month                   3914
# calculated_host_listings_count         0
# availability_365                       0
# instant_bookable                       0
# is_business_travel_ready               0
# require_guest_phone_verification       0
# require_guest_profile_picture          0
# dtype: int64

# %%
price0 = listings.loc[listings["price"]==0]
price0
listings = listings.drop(price0.index)
listings.loc[listings["price"]==0]
# Out:
# Empty DataFrame
# Columns: [listing_id, host_id, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, reviews_per_month, calculated_host_listings_count, availability_365, instant_bookable, is_business_travel_ready, require_guest_phone_verification, require_guest_profile_picture]
# Index: []

# %% [markdown]
# Overall data seems pretty clean, dropped all irrelevant/invalid values, ready to be modelled.
# I will just be using listings and calendar_summary already wrangled data.

# %%
listings.to_csv("../cleaned/listings.csv", index = False, header=True)

# %%
calendar_summary.to_csv("../cleaned/calendar_summary.csv", index = False, header=True)
